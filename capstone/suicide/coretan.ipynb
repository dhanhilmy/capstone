# %%
import pandas as pd

# %%
df_suic = pd.read_csv('suic_rate.csv')
df_suic
# Out:
#      Unnamed: 0      Country  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0             0  Afghanistan   4.9   5.0   5.0   5.0   5.0   5.0   4.9   4.8
# 1             1      Albania   4.9   4.5   4.6   4.8   4.8   7.5   7.8   8.1
# 2             2      Algeria   4.5   4.5   4.4   4.1   4.0   3.9   3.7   3.5
# 3             3    Argentina   9.1  10.3  10.2   9.7   8.7   8.6   8.6   8.3
# 4             4      Armenia   3.4   3.1   3.5   2.6   4.0   4.2   5.9   5.8
# ..          ...          ...   ...   ...   ...   ...   ...   ...   ...   ...
# 127         127      Uruguay  16.0  14.5  19.8  15.6  15.3  14.8  15.5  17.4
# 128         128   Uzbekistan  10.1  10.0   9.7   9.0   8.6   9.1   8.8   8.6
# 129         129      Vietnam   6.1   6.1   6.1   6.1   6.3   6.3   6.4   6.7
# 130         130       Zambia  13.3  12.4  12.1  11.6  12.2  11.9  11.7  10.3
# 131         131     Zimbabwe  13.3  12.8  13.4  13.2  14.2  14.0  14.4  17.2
#
# ...

# %%
df_suic.drop(['Unnamed: 0'], axis=1, inplace=True)
df_suic
# Out:
#          Country  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  \
# 0    Afghanistan   4.9   5.0   5.0   5.0   5.0   5.0   4.9   4.8   4.6  ...
# 1        Albania   4.9   4.5   4.6   4.8   4.8   7.5   7.8   8.1   8.2  ...
# 2        Algeria   4.5   4.5   4.4   4.1   4.0   3.9   3.7   3.5   3.4  ...
# 3      Argentina   9.1  10.3  10.2   9.7   8.7   8.6   8.6   8.3   8.7  ...
# 4        Armenia   3.4   3.1   3.5   2.6   4.0   4.2   5.9   5.8   4.8  ...
# ..           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 127      Uruguay  16.0  14.5  19.8  15.6  15.3  14.8  15.5  17.4  15.1  ...
# 128   Uzbekistan  10.1  10.0   9.7   9.0   8.6   9.1   8.8   8.6   8.5  ...
# 129      Vietnam   6.1   6.1   6.1   6.1   6.3   6.3   6.4   6.7   6.9  ...
# 130       Zambia  13.3  12.4  12.1  11.6  12.2  11.9  11.7  10.3   9.7  ...
# 131     Zimbabwe  13.3  12.8  13.4  13.2  14.2  14.0  14.4  17.2  20.1  ...
#
# ...

# %%
suic_view = df_suic.loc[:, ['Country', '2010', '2011',
                '2012', '2013', '2014', '2015', 
                '2016', '2017', '2018', '2019']].set_index('Country').T

# %%
suic_view.index = pd.to_datetime(suic_view.index)
suic_view.index
# Out:
# DatetimeIndex(['2010-01-01', '2011-01-01', '2012-01-01', '2013-01-01',
#                '2014-01-01', '2015-01-01', '2016-01-01', '2017-01-01',
#                '2018-01-01', '2019-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
suic_ov = pd.read_csv('suic_overall.csv', sep=';')
top_10 = suic_ov.sort_values(by='mean', ascending=False).head(10)
top_10.transpose()
# Out:
#              66         69       10            110         61       123  \
# Country  Lesotho  Lithuania  Belarus  South Africa  Kazakhstan  Ukraine
# 2010        65.4       37.2     35.9          24.6        29.9     24.5
# 2011        69.5       38.1     36.2          22.4        28.7     23.0
# 2012        79.1       35.0     29.9          22.9        27.6     23.1
# 2013        87.6       40.5     27.9          23.7        26.3     22.6
# 2014        92.6       35.6     26.3          24.1        24.2     24.4
# 2015        92.4       34.9     24.3          24.5        23.2     21.6
# 2016        87.0       32.8     24.2          24.4        21.7     21.4
# 2017        78.3       29.7     23.3          25.2        20.8     20.6
# 2018        76.6       27.4     22.8          24.1        19.0     21.9
# 2019        72.4       26.1     21.2          23.5        17.6     21.6
# mean       80.09      33.73     27.2         23.94        23.9    22.47
#
# ...
